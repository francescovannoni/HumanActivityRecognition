# %% [markdown]
# # Data pre-processing and Exploration Data Anaysis

# %%
import numpy as np
import pandas as pd

# get the features from the file features.txt
features = list()
with open('/home/frenk/Documenti/Artificial Intelligence/UCI_HAR_Dataset/features.txt') as f:
    features = f.readlines()
print('No of Features: {}'.format(len(features)))
# Out:
# No of Features: 561

# %%
# get the data from txt files to pandas dataframe
X_train = pd.read_csv("/home/frenk/Documenti/Artificial Intelligence/UCI_HAR_Dataset/train/X_train.txt", delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_train['subject'] = pd.read_csv('/home/frenk/Documenti/Artificial Intelligence/UCI_HAR_Dataset/train/subject_train.txt', header=None, squeeze=True)

y_train = pd.read_csv('/home/frenk/Documenti/Artificial Intelligence/UCI_HAR_Dataset/train/y_train.txt', names=['Activity'], squeeze=True)
y_train_labels = y_train.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})

# put all columns in a single dataframe
train = X_train
train['Activity'] = y_train
train['ActivityName'] = y_train_labels
train.head(10)
# Out:
#    1 tBodyAcc-mean()-X\n  2 tBodyAcc-mean()-Y\n  3 tBodyAcc-mean()-Z\n  \
# 0               0.288585              -0.020294              -0.132905
# 1               0.278419              -0.016411              -0.123520
# 2               0.279653              -0.019467              -0.113462
# 3               0.279174              -0.026201              -0.123283
# 4               0.276629              -0.016570              -0.115362
# 5               0.277199              -0.010098              -0.105137
# 6               0.279454              -0.019641              -0.110022
# 7               0.277432              -0.030488              -0.125360
# 8               0.277293              -0.021751              -0.120751
# 9               0.280586              -0.009960              -0.106065
#
#    4 tBodyAcc-std()-X\n  5 tBodyAcc-std()-Y\n  6 tBodyAcc-std()-Z\n  \
# 0             -0.995279             -0.983111             -0.913526
# 1             -0.998245             -0.975300             -0.960322
# 2             -0.995380             -0.967187             -0.978944
# 3             -0.996091             -0.983403             -0.990675
# 4             -0.998139             -0.980817             -0.990482
# 5             -0.997335             -0.990487             -0.995420
# 6             -0.996921             -0.967186             -0.983118
# 7             -0.996559             -0.966728             -0.981585
# 8             -0.997328             -0.961245             -0.983672
# 9             -0.994803             -0.972758             -0.986244
#
#    7 tBodyAcc-mad()-X\n  8 tBodyAcc-mad()-Y\n  9 tBodyAcc-mad()-Z\n  \
# 0             -0.995112             -0.983185             -0.923527
# 1             -0.998807             -0.974914             -0.957686
# 2             -0.996520             -0.963668             -0.977469
# 3             -0.997099             -0.982750             -0.989302
# 4             -0.998321             -0.979672             -0.990441
# 5             -0.997627             -0.990218             -0.995549
# 6             -0.997003             -0.966097             -0.983116
# 7             -0.996485             -0.966313             -0.982982
# 8             -0.997596             -0.957236             -0.984379
# 9             -0.995405             -0.973663             -0.985642
#
#    10 tBodyAcc-max()-X\n  ...  555 angle(tBodyAccMean,gravity)\n  \
# 0              -0.934724  ...                          -0.112754
# 1              -0.943068  ...                           0.053477
# 2              -0.938692  ...                          -0.118559
# 3              -0.938692  ...                          -0.036788
# 4              -0.942469  ...                           0.123320
# 5              -0.942469  ...                           0.082632
# 6              -0.940987  ...                          -0.212754
# 7              -0.940987  ...                          -0.020888
# 8              -0.940598  ...                           0.012954
# 9              -0.940028  ...                          -0.020590
#
#    556 angle(tBodyAccJerkMean),gravityMean)\n  \
# 0                                    0.030400
# 1                                   -0.007435
# 2                                    0.177899
# 3                                   -0.012892
# 4                                    0.122542
# 5                                   -0.143439
# 6                                   -0.230622
# 7                                    0.593996
# 8                                    0.080936
# 9                                   -0.127730
#
#    557 angle(tBodyGyroMean,gravityMean)\n  \
# 0                               -0.464761
# 1                               -0.732626
# 2                                0.100699
# 3                                0.640011
# 4                                0.693578
# 5                                0.275041
# 6                                0.014637
# 7                               -0.561871
# 8                               -0.234313
# 9                               -0.482871
#
#    558 angle(tBodyGyroJerkMean,gravityMean)\n  559 angle(X,gravityMean)\n  \
# 0                                   -0.018446                   -0.841247
# 1                                    0.703511                   -0.844788
# 2                                    0.808529                   -0.848933
# 3                                   -0.485366                   -0.848649
# 4                                   -0.615971                   -0.847865
# 5                                   -0.368224                   -0.849632
# 6                                   -0.189512                   -0.852150
# 7                                    0.467383                   -0.851017
# 8                                    0.117797                   -0.847971
# 9                                   -0.070670                   -0.848294
#
#    560 angle(Y,gravityMean)\n  561 angle(Z,gravityMean)\n  subject  Activity  \
# 0                    0.179941                   -0.058627        1         5
# 1                    0.180289                   -0.054317        1         5
# 2                    0.180637                   -0.049118        1         5
# 3                    0.181935                   -0.047663        1         5
# 4                    0.185151                   -0.043892        1         5
# 5                    0.184823                   -0.042126        1         5
# 6                    0.182170                   -0.043010        1         5
# 7                    0.183779                   -0.041976        1         5
# 8                    0.188982                   -0.037364        1         5
# 9                    0.190310                   -0.034417        1         5
#
#    ActivityName
# 0      STANDING
# 1      STANDING
# 2      STANDING
# 3      STANDING
# 4      STANDING
# 5      STANDING
# 6      STANDING
# 7      STANDING
# 8      STANDING
# 9      STANDING
#
# [10 rows x 564 columns]

# %% [markdown]
# Do the same thing for test data

# %%
# get the data from txt files to pandas dataffame
X_test = pd.read_csv('/home/frenk/Documenti/Artificial Intelligence/UCI_HAR_Dataset/test/X_test.txt', delim_whitespace=True, header=None, names=features)

# add subject column to the dataframe
X_test['subject'] = pd.read_csv('/home/frenk/Documenti/Artificial Intelligence/UCI_HAR_Dataset/test/subject_test.txt', header=None, squeeze=True)

# get y labels from the txt file
y_test = pd.read_csv('/home/frenk/Documenti/Artificial Intelligence/UCI_HAR_Dataset/test/y_test.txt', names=['Activity'], squeeze=True)
y_test_labels = y_test.map({1: 'WALKING', 2:'WALKING_UPSTAIRS',3:'WALKING_DOWNSTAIRS',\
                       4:'SITTING', 5:'STANDING',6:'LAYING'})


# put all columns in a single dataframe
test = X_test
test['Activity'] = y_test
test['ActivityName'] = y_test_labels
test.sample()
# Out:
#       1 tBodyAcc-mean()-X\n  2 tBodyAcc-mean()-Y\n  3 tBodyAcc-mean()-Z\n  \
# 1093               0.267629              -0.000258              -0.074261
#
#       4 tBodyAcc-std()-X\n  5 tBodyAcc-std()-Y\n  6 tBodyAcc-std()-Z\n  \
# 1093             -0.947056             -0.882141             -0.906665
#
#       7 tBodyAcc-mad()-X\n  8 tBodyAcc-mad()-Y\n  9 tBodyAcc-mad()-Z\n  \
# 1093             -0.951862             -0.893189             -0.912535
#
#       10 tBodyAcc-max()-X\n  ...  555 angle(tBodyAccMean,gravity)\n  \
# 1093              -0.925282  ...                           0.130774
#
#       556 angle(tBodyAccJerkMean),gravityMean)\n  \
# 1093                                   -0.202235
#
#       557 angle(tBodyGyroMean,gravityMean)\n  \
# 1093                                 0.52057
#
#       558 angle(tBodyGyroJerkMean,gravityMean)\n  559 angle(X,gravityMean)\n  \
# 1093                                   -0.460632                   -0.860622
#
#       560 angle(Y,gravityMean)\n  561 angle(Z,gravityMean)\n  subject  \
# 1093                    0.190747                   -0.010085       10
#
#       Activity  ActivityName
# 1093         4       SITTING
#
# [1 rows x 564 columns]

# %% [markdown]
# # Working on datas

# %%
# Check for duplicates and for Nan/Null values

# %%
print('No of duplicates in train: {}'.format(sum(train.duplicated())))
print('No of duplicates in test : {}'.format(sum(test.duplicated())))
# Out:
# No of duplicates in train: 0
# No of duplicates in test : 0

# %%
print('{} NaN/Null values in train'.format(train.isnull().values.sum()))
print('{} NaN/Null values in test'.format(test.isnull().values.sum()))
# Out:
# 0 NaN/Null values in train
# 0 NaN/Null values in test

# %% [markdown]
# Let's check about data provided by each user

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')
plt.rcParams['font.family'] = 'DejaVu Sans'

plt.figure(figsize=(16,8))
plt.title('Data from each user', fontsize=20)
sns.countplot(x='subject',hue='ActivityName', data = train)
plt.show()

# %% [markdown]
# # Data per Activity

# %%
plt.title('No of Datapoints per Activity', fontsize=15)
sns.countplot(train.ActivityName)
plt.xticks(rotation=45)
plt.show()

# %%
count_of_each_activity = np.array(y_train.value_counts())
activities = sorted(y_train.unique())

# Plot a pie chart for different activities
plt.rcParams.update({'figure.figsize': [10, 10], 'font.size': 20})
plt.pie(count_of_each_activity, labels = ['Standing', 'Sitting', 'Laying', 'Walking', 'Walking Downstairs', 'Walking Upstairs'], autopct = '%0.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd202000f90>,
#   <matplotlib.patches.Wedge at 0x7fd20200f690>,
#   <matplotlib.patches.Wedge at 0x7fd20200fe50>,
#   <matplotlib.patches.Wedge at 0x7fd202018690>,
#   <matplotlib.patches.Wedge at 0x7fd2020240d0>,
#   <matplotlib.patches.Wedge at 0x7fd202024950>],
#  [Text(0.9071064061014833, 0.6222201925441275, 'Standing'),
#   Text(-0.23874635466468208, 1.073778458591122, 'Sitting'),
#   Text(-1.0745883152841482, 0.2350743555872831, 'Laying'),
#   Text(-0.7193129027755119, -0.832219290752544, 'Walking'),
#   Text(0.29301586483507763, -1.0602554894717366, 'Walking Downstairs'),
#   Text(1.0038008332903794, -0.4498709671511826, 'Walking Upstairs')],
#  [Text(0.4947853124189908, 0.3393928322967968, '19.14'),
#   Text(-0.13022528436255384, 0.5856973410497028, '18.69'),
#   Text(-0.5861390810640807, 0.12822237577488166, '17.49'),
#   Text(-0.3923524924230064, -0.453937794955933, '16.68'),
#   Text(0.15982683536458778, -0.5783211760754926, '14.59'),
#   Text(0.5475277272492978, -0.24538416390064502, '13.41')])

# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import seaborn as sns

def perform_tsne(X_data, y_data):
        
        # perform t-sne
        X_reduced = TSNE(perplexity).fit_transform(X_data)
        
        # prepare the data for seaborn      
        df = pd.DataFrame({'x':X_reduced[:,0], 'y':X_reduced[:,1] ,'label':y_data})
        
        # draw the plot in appropriate place in the grid
        sns.lmplot(data=df, x='x', y='y', hue='label', fit_reg=False, size=8,\
                   palette="Set1",markers=['^','v','s','o', '1','2'])
        plt.show()
        print('Done')

# %%
X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
y_pre_tsne = train['ActivityName']
perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-80b4ac42515e> in <module>
#       1 X_pre_tsne = train.drop(['subject', 'Activity','ActivityName'], axis=1)
#       2 y_pre_tsne = train['ActivityName']
# ----> 3 perform_tsne(X_data = X_pre_tsne,y_data=y_pre_tsne)
#
# <ipython-input-12-25358890c3c7> in perform_tsne(X_data, y_data)
#       7
#       8         # perform t-sne
# ----> 9         X_reduced = TSNE(perplexity).fit_transform(X_data)
#      10
#      11         # prepare the data for seaborn
#
# NameError: name 'perplexity' is not defined
